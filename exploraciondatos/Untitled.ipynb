# %%
import pandas as pd
import datascience as dt
import numpy as np
import matplotlib.pylab as plt

# %%
df = pd.read_csv("poblacion_proyeccion_201.csv")

# %%
df.to_csv("poblacion_proyeccion_201.csv", encoding="utf-8")

# %%
# !ls
# Out:
# Untitled.ipynb                poblacion__proyeccion_201.csv

# %%
mv po
