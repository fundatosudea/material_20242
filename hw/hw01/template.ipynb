# %% [raw]
# # BEGIN QUESTION
# name: q6_2

# %% [markdown]
# Escriba aca su pregunta

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
respuesta_supervivientes = 1

# END SOLUTION
""" # BEGIN PROMPT
respuesta_supervivientes = ...
""" # END PROMPT

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
assert respuesta_supervivientes==1

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION
