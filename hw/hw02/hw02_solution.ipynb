# %% [raw]
# # ASSIGNMENT CONFIG
#
# solutions_pdf: False
# export_cell:
#     instructions: "These are some submission instructions."
# generate:
#     pdf: false
#     filtering: false
#     pagebreaks: false
#     zips: false

# %%
pip install otter-grader
pip install datascience
# Out:
#   Input In [1]
#     pip install otter-grader
#         ^
# SyntaxError: invalid syntax

# %%
import otter
import numpy as np
# %matplotlib inline
import otter
import matplotlib.pylab as plt
grader = otter.Notebook()

# %% [markdown]
# 1. Creando arreglos

# %% [markdown]
# En clase, contamos el número de veces que caracteres aparecen en cada capítulo del libro clásico [*Little Women*](https://inferentialthinking.com/chapters/01/3/1/Literary_Characters.html?highlight=little%20women).  En ciencias computacionales, la palabra "caracter" también hace referencia a una letra, dígito, espacio o signo de puntuación; cada elemento de un texto. El siguiente código genera una gráfica de dispersión en la cual cada punto corresponde a un capítulo de *Little Women*. La posición horizontal de un punto mide el número de puntos en un capítulo. La posición vertical midel el número total de caracteres.

# %%
# Ejecute esta celda para configurar su notebook, pero por favor no la cambie.

import numpy as np
from datascience import *
import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [raw]
# # BEGIN QUESTION
# name: q1_1

# %% [markdown]
# **Pregunta 1.** Cree un arreglo llamado `numeros_extraños` que contenga los siguientes números (en el orden dado) **(4 Points)**:
#
# 1. -2
# 2. El piso (floor) de 17.6
# 3. 3
# 4. 5 a la potencia del techo (ceil) de 5.3
#
# *Hint:* `floor` y `ceil` son funciones en el módulo `math`. Importar módulos se trabaja en el Lab 2.
#
# *Nota:* Las listas de Python son y se comportan diferente de los arreglos de NumPy. En este curso usaremos arreglos de NumPy, así que cuando haga un **arreglo**, no haga una lista de Python.

# %% [raw]
# # BEGIN SOLUTION

# %%
import math

# %%
# BEGIN SOLUTION NO PROMPT
numeros_extraños = np.array((-2,math.floor(17.6), 3, math.ceil(5.3)))
# END SOLUTION
""" # BEGIN PROMPT
numeros_extraños = ...
""" # END PROMPT
numeros_extraños
# Out:
# array([-2, 17,  3,  6])

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
isinstance(numeros_extraños, np.ndarray)
# Out:
# True

# %%
numeros_extraños[0] == -2
# Out:
# True

# %%
numeros_extraños[1] == 17
# Out:
# True

# %%
numeros_extraños[2] == 3
# Out:
# True

# %%
numeros_extraños[3] == 6
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q1_2

# %% [markdown]
# **Pregunta 2.** Cree un arreglo llamado `titulo_libros` que contenga las tres siguientes cadenas de caracteres: "Eats", "Shoots", and "and Leaves". **(4 Puntos)**

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
titulo_libros = np.array(('Eats', 'Shoots', 'and Leaves'))
# END SOLUTION
""" # BEGIN PROMPT
titulo_libros = ...
""" # END PROMPT
titulo_libros
# Out:
# array(['Eats', 'Shoots', 'and Leaves'],
#       dtype='<U10')

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
isinstance(titulo_libros, np.ndarray)
# Out:
# True

# %%
titulo_libros.dtype == '<U10'
# Out:
# True

# %%
titulo_libros[0] == 'Eats'
# Out:
# True

# %%
titulo_libros[1] == 'Shoots'
# Out:
# True

# %%
titulo_libros[2] == 'and Leaves'
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q1_3

# %% [markdown]
# Las cadenas de caracteres (strings) tienen un método llamado `join`. `join` toma como argumento un arreglo de cadenas de caracteres y regresa una cadena de caracteres. Específicamente, el resultado es una sola cadena de caracteres, que es la [concatenación](https://es.wikipedia.org/wiki/Concatenaci%C3%B3n) ("juntar") todas las cadenas de caracteres en el arreglo.
#
#
# **Pregunta 3.** Use el arreglo `titulo_libros` y el método `join` para crear dos arreglos **(4 Puntos)**:
#
# 1. "Eats, Shoots, and Leaves" (llámelo `usando_comas`)
# 2. "Eats Shoots and Leaves" (llámelo `sin_comas`)

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
usando_comas = np.array(("Eats, Shoots, and Leaves" ))
sin_comas = np.array(("Eats Shoots and Leaves"))

# END SOLUTION
""" # BEGIN PROMPT
usando_comas = ...
sin_comas = ...
""" # END PROMPT
print('usando_comas:', usando_comas)
print('sin_comas:', sin_comas)
# Out:
# usando_comas: Eats, Shoots, and Leaves
# sin_comas: Eats Shoots and Leaves

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
isinstance(usando_comas, np.ndarray) and isinstance(sin_comas, np.ndarray)
# Out:
# True

# %%
usando_comas == 'Eats, Shoots, and Leaves'
# Out:
# array(True, dtype=bool)

# %%
sin_comas == "Eats Shoots and Leaves"
# Out:
# array(True, dtype=bool)

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# ## Indexando arreglos

# %% [raw]
# # BEGIN QUESTION
# name: q2_1

# %% [markdown]
# Estos ejercicios están pensados en dar práctica al momento de acceder a elementos individuales de los arreglos. En Python (y en muchos lenguajes de programación), cada elemento es accesible mediante su  *índice*; por ejemplo, el primer elmento es el elemento con índice 0. Los índices deben ser números **enteros**.
#
#
# ***Nota:* Si usted tiene experiencia previa programando, la notación de corchetes le debe ser familiar. NO use la notación de corchetes cuando esté indexando (i.e. `arr[0]`), pues esto puede conducir a un tipo de dato diferente del que estamos esperando. Le puede además hacer fallar en la revisión.**
#
# En caso de sentirse atascado, revise la [Referencia de Python](http://data8.org/fa23/reference/)

# %% [markdown]
# **Pregunta 1.** La siguiente celda crea un arreglo de algunos números. Asigne `tercer_elemento`  al tercer elemento de `algunos_numeros`. **(4 Puntos)**

# %%
algunos_numeros = make_array(-1, -3, -6, -10, -15)

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
tercer_elemento = -6
# END SOLUTION
""" # BEGIN PROMPT
tercer_elemento = ...
""" # END PROMPT
tercer_elemento
# Out:
# -6

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
tercer_elemento == -6 or tercer_elemento == -6.0
# Out:
# True

# %%
type(tercer_elemento) == int or type(tercer_elemento) == float
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q2_2

# %% [markdown]
# **Pregunta 2.** La próxima celda crea una tabla que muestra información sobre los elementos de `algunos_numeros` y su orden. Corra la celda para ver la tabla parcialmente completa y llene la información faltante (las celdas que dicen "Ellipsis") mediante la asignación `espacio_a`, `espacio_b`, `espacio_c`, y `espacio_d` para corregir los elementos en la tabla. **(4 Puntos)**
#
# *Hint* Reemplace los `...` con cadenas de caracteres o números. Recuerde que los índices deben ser **enteros**.

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
espacio_a = "tercero"
espacio_b = "cuarto"
espacio_c = 0
espacio_d = 3
elementos_de_algunos_numeros = Table().with_columns(
    "Nombre de la posicion", make_array("primero", "segundo", espacio_a, espacio_b, "quinto"),
    "Idice",                     make_array(espacio_c, 1, 2, espacio_d, 4),
    "Elemento",                   algunos_numeros)
# END SOLUTION

""" # BEGIN PROMPT
espacio_a = ...
espacio_b = ...
espacio_c = ...
espacio_d = ...
elementos_de_algunos_numeros = Table().with_columns(
    "Nombre de la posicion", make_array("primero", "segundo", espacio_a, espacio_b, "quinto"),
    "Idice",                     make_array(espacio_c, 1, 2, espacio_d, 4),
    "Elemento",                   algunos_numeros)

""" # END PROMPT
elementos_de_algunos_numeros
# Out:
# Nombre de la posicion | Idice | Elemento
# primero               | 0     | -1
# segundo               | 1     | -3
# tercero               | 2     | -6
# cuarto                | 3     | -10
# quinto                | 4     | -15

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
isinstance(elementos_de_algunos_numeros, Table)
# Out:
# True

# %%
espacio_a == "tercero" and espacio_b == "cuarto" and espacio_c == 0 and espacio_d == 3
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q2_3

# %% [markdown]
# **Pregunta 3.** En ocasiones usted querrá encontrar el **último** elemento de un arreglo. Suponga que el arreglo tiene 142 elementos. ¿Cuál es el índice del último elemento? **(4 Puntos)**
#
# *Nota:* Su respuesta deberá ser un número positivo.

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
indice_ultimo_elemento = 141

""" # BEGIN PROMPT
indice_ultimo_elemento = ...

""" # END PROMPT
indice_ultimo_elemento
# Out:
# 141

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
indice_ultimo_elemento == 141
# Out:
# True

# %%
type(indice_ultimo_elemento) == int
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q2_4

# %% [markdown]
# Con frecuencia, usted no conocerá el número de elementos de un arreglo, su *longitud*. (Por ejemplo, puede ser un conjunto de datos que usted encuentra en Internet.) La función `len` toma un solo argumento, un arreglo, y entrega un número entero que representa la longitud o tamaño de dicho arreglo.
#
# **Pregunta 4.** La siguiente celda carga un arreglo llamado `año_nacimiento_presidentes`. Llamando `tabla.column(...)` en una tabla entrega un arreglo con la columna especificada, en este caso la columna `Año de nacimiento` de la tabla `nacimiento_presidentes`. El último elemento en ese arreglo es el más reciente entre los años de nacimiento entre todos los ex-presidentes de los Estados Unidos. Asigne ese año a `año_nacimiento_mas_reciente` **(4 Puntos)**
#
#
# **Nota:** Evite googlear la respuesta. Usted debería ser capaz de responder esta pregunta únicamente usando métodos de tablas.

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
año_nacimiento_presidentes = Table.read_table("president_births.csv").column('Birth Year')  #Modificar una vez se ajuste la tabla.
most_recent_birth_year = año_nacimiento_presidentes[-1]

""" # BEGIN PROMPT
most_recent_birth_year = ...

""" # END PROMPT
most_recent_birth_year
# Out:
# 1917

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
most_recent_birth_year == 1917
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q3_1

# %% [markdown]
# ## Artimética básica de arreglos

# %% [markdown]
# **Pregunta 1.** Multiplique los números 42, -4224, 424224242, y 250 por 157. Asigne cada variable en la siguiente celda de tal forma que  `primer_producto` se asigne al resultado de $42 * 157$, `segundo_producto` al resultado de $-4224 * 157$ y así sucesivamente. **(4 Puntos)**
#
# *Nota*: Para esta pregunta, **no** use arreglos.

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
primer_producto = 42 * 157
segundo_producto =  -4224 * 157
tercer_producto = 424224242 * 157
cuarto_producto = 250 * 157

""" # BEGIN PROMPT
primer_producto = ...
segundo_producto = ...
tercer_producto = ...
cuarto_producto = ...

""" # END PROMPT
print("Primer Producto:", primer_producto)
print("Segundo Producto:", segundo_producto)
print("Tercer Producto:", tercer_producto)
print("Cuarto Producto:", cuarto_producto)
# Out:
# Primer Producto: 6594
# Segundo Producto: -663168
# Tercer Producto: 66603205994
# Cuarto Producto: 39250

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
primer_producto == 6594 and segundo_producto == -663168 and tercer_producto == 66603205994 and cuarto_producto == 39250
# Out:
# True

# %%
type(primer_producto) == int and type(segundo_producto) == int and type(tercer_producto) == int and type(cuarto_producto) == int
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q3_2

# %% [markdown]
# **Pregunta 2.** Ahora, haga los mismos cálculos, pero esta vez usando un arreglo llamado `numeros`y un solo operador de multiplicación (`*`). Almacene los 4 resultados en un arreglo llamado `productos`. **(4 Puntos)**

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
numeros = np.array([42,-4224,424224242,250])
productos = numeros * 157
""" # BEGIN PROMPT
numeros = ...
productos = ...
""" # END PROMPT
productos
# Out:
# array([       6594,     -663168, 66603205994,       39250])

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
len(productos) == 4
# Out:
# True

# %%
productos[0] == 6594 and productos[1] == -663168 and productos[2] == 66603205994 and productos[3] == 39250
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q3_3

# %% [markdown]
# **Pregunta 3.** Ups, cometimos un error. En lugar de 157, queremos que multiplique cada número por 1577. Calcule los productos correctos en la celda de abajo usando aritmética de arreglos. Note que su trabajo es realmente sencillo si previamente definió un arreglo que contiene los 4 números. **(4 Puntos)**

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
productos_correctos = numeros * 1577

""" # BEGIN PROMPT
productos_correctos = ...

""" # END PROMPT
productos_correctos
# Out:
# array([       66234,     -6661248, 669001629634,       394250])

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
len(productos_correctos) == 4
# Out:
# True

# %%
productos_correctos[0] == 66234 and productos_correctos[1] == -6661248 and productos_correctos[2] == 669001629634 and productos_correctos[3] == 394250
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q3_4

# %% [markdown]
# Estudiando a los sobrevivientes

# %% [markdown]
# **Pregunta 4.** Hemos cargado un arreglo de temperaturas en la siguiente celda. Cada número es la temperatura más alta registrada en un día en una estación de medición del clima. Al ser datos de la agencia gubernamental de Estados Unidos [NOAA](https://www.noaa.gov/), todas las temperaturas están en Fahrenheit.
#
# Convierta todas las temperaturas a Celsius, primero sustrayendo 32 de ellas. Luego, multiplique los resultados por by $\frac{5}{9}$, i.e. $C = (F - 32) * \frac{5}{9}$. Luego de convertir las temperaturas a Celsius, asegúrese de **REDONDEAR** el resultado final al entero más cercano usando la función `np.round`. **(4 Puntos)**

# %%
max_temps = Table.read_table("temperatures.csv").column("Daily Max Temperature") #Modificar una vez se ajuste la tabla.

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
celsius_max_temps = (max_temps - 32) * (5/9)
celsius_temps_redondeadas = np.round(celsius_max_temps)

""" # BEGIN PROMPT
celsius_max_temps = ...
celsius_temps_redondeadas = ...

""" # END PROMPT
celsius_temps_redondeadas
# Out:
# array([ -4.,  31.,  32., ...,  17.,  23.,  16.])

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
isinstance(celsius_temps_redondeadas, np.ndarray)
# Out:
# True

# %%
len(celsius_temps_redondeadas) == 65000
# Out:
# True

# %%
celsius_temps_redondeadas.dtype == 'float64'
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q3_5

# %% [markdown]
# **Pregunta 5.** La celda de abajo carga todas las más *bajas* temperaturas de cada día (en Fahrenheit). Calcule el intervalo diario de temperaturas de cada día. Esto es, calcule la diferencia, por día, entre las respectivas temperaturas máxima y mínima. **¡Preste atención a las unidades y de su respuesta en Celsius!** Asegúrese de **NO** redondear su respuesta.
#
#
# *Hint:* Use `min_temps` y/o `max_temps`, y preste atención a la conversión de unidades. Escriba el cálculo matemático a mano si no logra avanzar.

# %%
min_temps = Table.read_table("temperatures.csv").column("Daily Min Temperature")

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
celsius_min_temps = (min_temps - 32) * (5/9)
celsius_temps_rangos = celsius_max_temps - celsius_min_temps

""" # BEGIN PROMPT
celsius_temps_rangos = ...

""" # END PROMPT
celsius_temps_rangos
# Out:
# array([  6.66666667,  10.        ,  12.22222222, ...,  17.22222222,
#         11.66666667,  11.11111111])

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
isinstance(celsius_temps_rangos, np.ndarray)
# Out:
# True

# %%
celsius_temps_rangos.dtype == 'float64'
# Out:
# True

# %%
celsius_temps_rangos[0] == 6.6666666666666661 and celsius_temps_rangos[-1] == 11.111111111111111
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [markdown]
# ## 4. Old Faithful
#
# *Old* Faithful es un geyser en Yellowstone que erupciona cada 44-125 minutos (de acuerdo con [Wikipedia](https://es.wikipedia.org/wiki/Old_Faithful#:~:text=El%20Old%20Faithful%2C%20traducido%20al,%2C%20en%20Wyoming%2C%20Estados%20Unidos)). A las personas se les dice con frecuencia que erupciona cada una hora, pero de hecho el tiempo de espera entre erupciones es más variable. Veámoslo.

# %% [raw]
# # BEGIN QUESTION
# name: q4_1

# %% [markdown]
# **Pregunta 1.** La primera línea de la celda de abajo asigna `tiempos_espera` a un arreglo con 272 tiempos de espera consecutivos entre erupciones, tomados de un conjunto de datos de 1938. Asigne los nombres `menor`, `mayor` y `promedio`de forma tal que la asignación `print` esté correcta. **(4 Puntos)**

# %%
tiempos_espera = Table.read_table('old_faithful.csv').column('waiting')

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
menor = np.min(tiempos_espera)
mayor = np.max(tiempos_espera)
promedio = np.mean(tiempos_espera)

""" # BEGIN PROMPT
menor = ...
mayor = ...
promedio = ...

""" # END PROMPT
print("Old Faithful erupciona cada", menor, "a", mayor, "minutos y cada", promedio, "minutos en promedio.")
# Out:
# Old Faithful erupciona cada 43 a 96 minutos y cada 70.8970588235 minutos en promedio.

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
isinstance(promedio, float) and isinstance(menor, np.int64) and isinstance(mayor, np.int64)
# Out:
# True

# %%
promedio > 69 and promedio < 71
# Out:
# True

# %%
menor == 43
# Out:
# True

# %%
mayor == 96
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q4_2

# %% [markdown]
# **Pregunta 2.** Asigne `mayor_diferencia` al mayor cambio en la espera entre dos erupciones consecutivas. Por ejemplo, la tercera erupción ocurrió luego de 74 minutos y la cuarta luego de 62 minutos, así que la diferencia fue 74 - 62 = 12 minutos. **(4 Puntos)**
#
# *Hint*: Queremos el valor absoluto del valor de la mayor diferencia.
#
# *Nota*: `np.diff()` calcula la diferencia entre valores subsecuentes en un arreglo. Por ejemplo, llamando `np.diff()` en el arreglo `make_array(1, 8, 3, 5)`, evalúa `array([8 - 1, 3 - 8, 5 - 3])` o `array([7, -5, 2])`.

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
diferencias = np.diff(tiempos_espera)
mayor_diferencia = np.max(diferencias)

""" # BEGIN PROMPT
mayor_diferencia = ...

""" # END PROMPT
mayor_diferencia
# Out:
# 47

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
mayor_diferencia == 47
# Out:
# True

# %%
isinstance(mayor_diferencia, np.int64)
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q4_3

# %% [markdown]
# **Pregunta 3.** La tabla `faithful_erupcion_nums` contiene dos columnas: `numero_erupcion`, la cual representa el número de esa erupción, y `espera`, que indica el tiempo que se tuvo que esperar luego de esa erupción. Por ejemplo, tome las primeras dos filas de la tabla:
#
# | Número de erupción | Espera  |
# |--------------------|---------|
# | 1                  | 79      |
# | 2                  | 54      |
#
# Podemos leer esto como sigue: luego de la primera erupción, esperamos 79 minutos hasta que ocurrió la segunda erupción. Así, luego de la segunda erupción, esperamos 54 minutos por la tercera erupción.
#
# Suponga que Oscar y Wendy comenzaron viendo al Old Faithful al principio de la primera erupción. Suponga que ellos observan hasta el final de la décima erupción.
#
# Durante parte de ese tiempo estarán observando erupciones, y por el resto del tiempo estarán esperando que Old Faithful haga erupción. ¿Cuántos minutos pasarán esperando que ocurran erupciones? **(4 Puntos)**
#
# *Hint #1:* Puede iniciar usando el método `take` en la tabla `faithful_erupcion_nums`.
#
# *Hint #2:* `tiempo_espera_primeras_nueve` deberá ser un arreglo.

# %%
# Las siguientes dos líneas de código cargan la tabla faithful_erupcion_nums
faithful = Table.read_table('old_faithful.csv').drop("eruptions")
faithful_erupcion_nums = faithful.with_column("eruption number", np.arange(faithful.num_rows) + 1).select(1, 0)

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
tiempo_espera_primeras_nueve = faithful_erupcion_nums.take[:9]
tiempo_espera_primeras_nueve = tiempo_espera_primeras_nueve.column(1)
tiempo_total_espera_decima = np.sum(tiempo_espera_primeras_nueve)


""" # BEGIN PROMPT
tiempo_espera_primeras_nueve = ...
tiempo_total_espera_decima = ...

""" # END PROMPT
tiempo_total_espera_decima
# Out:
# 633

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
633 <= tiempo_total_espera_decima <= 718
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q4_4

# %% [markdown]
# **Pregunta 4.** Imaginemos que su estimación del siguiente tiempo de espera siempre fue la duración del tiempo de espera anterior. Si siempre adivinara el tiempo de espera anterior, ¿qué tan grande sería, en promedio, el error al adivinar los tiempos de espera?
#
# Por ejemplo, dado que los primeros cuatro tiempos de espera son 79, 54, 74 y 62, la diferencia promedio entre su "predicción" y el tiempo real solo para la segunda, tercera y cuarta erupciones sería: $\frac{|79-54|+ |54-74|+ |74-62|}{3} = 19$.

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
diferencias = np.diff(tiempos_espera)
error_promedio = np.sum(abs(diferencias))/(len(diferencias)-1)

""" # BEGIN PROMPT
error_promedio = ...

""" # END PROMPT
error_promedio
# Out:
# 20.596296296296295

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
20 < error_promedio < 21
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q5_1

# %% [markdown]
# ## 5. Tablas

# %% [markdown]
# **Pregunta 1.** Suponga que tiene 4 manzanas y 3 piñas. (Quizás esté usando Python para resolver un problema de álgebra del bachillerato.)Cree una tabla que contenga esta información. Esta deberá contener dos columnas: `nombre de la fruta` y `cantidad`. Asigne la nueva tabla a la variable `frutas`. **(4 Puntos)**
#
#
#
# *Note:* Use letras minúsculas y una sola palabra para el nombre de cada fruta, por ejemplo `"manzana"`.

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
frutas = Table

""" # BEGIN PROMPT
frutas = ...
        ...
        ...

""" # END PROMPT
arreglo
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 # BEGIN SOLUTION NO PROMPT
# ----> 2 Table.foo(1, 2, 'hello', 'world')
#       4 Table.from_array(arreglo)
#       5 """ # BEGIN PROMPT
#       6 frutas = ...
#       7         ...
#       8         ...
#       9
#      10 """ # END PROMPT
#
# AttributeError: type object 'Table' has no attribute 'foo'

# %%
for x in range(1,11):
    print ('{3}{0:2d}{3} {3}{1:3d}{3} {3}{2:4d}{3}'.format(x, x * x, x * x * x, '|'))
# Out:
# | 1| |  1| |   1|
# | 2| |  4| |   8|
# | 3| |  9| |  27|
# | 4| | 16| |  64|
# | 5| | 25| | 125|
# | 6| | 36| | 216|
# | 7| | 49| | 343|
# | 8| | 64| | 512|
# | 9| | 81| | 729|
# |10| |100| |1000|

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
entregas == 4
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q7_7

# %% [markdown]
# **Pregunta 7.** Tiene el curso de Fundamentos de Ciencia de Datos alternativas para el examen final para aquellos que tienen inconvenientes con el horario de las clases? Asigne `examen` el número correspondiente con la mejor elección. **(3 Puntos)**
#
# 1. Sí
# 2. No

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
examen = 1

""" # BEGIN PROMPT
examen = ...

""" # END PROMPT
examen
# Out:
# 1

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
examen == 1
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q7_8

# %% [markdown]
# **Pregunta 8:** ¿Está usted en efecto inscrito en la plataforma? Vaya a las publicaciones de este semestre y encuentre la frase secreta que publicó el instructor del curso. Asigne `secreto` a dicha frase en comillas (como una cadena de caracteres). **(4 Puntos)**

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
secreto = "El objetivo es convertir los datos en informacion y la informacion en conocimiento"

""" # BEGIN PROMPT
secreto = ...

""" # END PROMPT
secreto
# Out:
# 'El objetivo es convertir los datos en informacion y la informacion en conocimiento'

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
x = secreto.lower()
x == "el objetivo es convertir los datos en informacion y la informacion en conocimiento"
# Out:
# True

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION
