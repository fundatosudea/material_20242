# %% [raw]
# # ASSIGNMENT CONFIG
# name: "holaMundo"
# solutions_pdf: true
# export_cell:
#     instructions: "These are some submission instructions."
# generate:
#     pdf: true
#     filtering: true
#     pagebreaks: true
#     zips: false

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from datascience import *
path="https://raw.githubusercontent.com/fundatosudea/material_20242/develop_otter"

# %% [raw]
# # BEGIN QUESTION
# name: qt
# manual: true
# points: 0

# %% [markdown]
# # Laboratorio número 2

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
Nomre="Ingrese"
NumCarnet="1111"
# END SOLUTION
""" # BEGIN PROMPT
Nombre="..."
NumCarnet=".."
""" # END PROMPT

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
assert isinstance(Nombre, str)
assert isinstance(NumCarnet, str)
assert len(Nombre)>3
assert len(NumCarnet)>3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 assert isinstance(Nombre, str)
#       2 assert isinstance(NumCarnet, str)
#       3 assert len(Nombre)>3
#
# NameError: name 'Nombre' is not defined

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION

# %% [raw]
# # BEGIN QUESTION
# name: q1
# manual: false
# points: 1

# %% [markdown]
# P1. Esta es una pregunta de pruena

# %% [raw]
# # BEGIN SOLUTION

# %%
# BEGIN SOLUTION NO PROMPT
characters_q1 = 5
# END SOLUTION
""" # BEGIN PROMPT
characters_q1 = ...
""" # END PROMPT
# Out:
# ' # BEGIN PROMPT\ncharacters_q1 = ...\n'

# %% [raw]
# # END SOLUTION

# %% [raw]
# # BEGIN TESTS

# %%
assert (characters_q1 == 5)

# %% [raw]
# # END TESTS

# %% [raw]
# # END QUESTION
